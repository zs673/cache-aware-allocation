# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C467B0A9F0>

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("4", "8", "12", "16", "32")
penguin_means = {
    'HEFT': (9528.009,4981.475,3965.3,3546.787,2787.464),
    'CPOP': (9519.921,5008.453,3998.538,3576.738,2900.771),
    'ranku + New': (9515.073,4926.135,3893.89,3462.542,2729.576),
    'New priority + EFT': (9466.162,4899.913,3862.21,3430.597,2691.706),
    'OUR': (9417.898,4772.568,3660.439,3202.689,2518.914),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Makespan', fontsize=20)
ax.set_title('Cores', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.15)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/core_makespan.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("4", "8", "12", "16", "32")
penguin_means = {
    'HEFT': (4.836,3.016,2.378,2.116,1.727),
    'CPOP': (4.831,3.027,2.39,2.126,1.787),
    'ranku + New': (4.832,2.986,2.334,2.067,1.692),
    'New priority + EFT': (4.806,2.965,2.314,2.043,1.666),
    'OUR': (4.787,2.894,2.192,1.903,1.548),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SLR', fontsize=20)
ax.set_title('Cores', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.15)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/core_SLR.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("4", "8", "12", "16", "32")
penguin_means = {
    'HEFT': (2.354,3.751,4.75,5.342,6.556),
    'CPOP': (2.355,3.736,4.724,5.312,6.336),
    'ranku + New': (2.356,3.789,4.841,5.468,6.696),
    'New priority + EFT': (2.368,3.814,4.88,5.53,6.803),
    'OUR': (2.378,3.91,5.152,5.934,7.33),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Speedup', fontsize=20)
ax.set_title('Cores', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-0.17, 0)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.legend(bbox_to_anchor=(0.01,0.01), loc=3, borderaxespad=0)
plt.savefig('./figs/core_speed.pdf')
plt.show()
