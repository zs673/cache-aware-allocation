# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C467B0A9F0>

# %% [markdown]
# # rank_u vs new priority -- sensitivity

# %% [markdown]
# 1. layers

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (5707.863,5112.285,4710.195,4460.958,4257.141),
    'New priority + EFT': (5561.803,5009.492,4635.313,4397.563,4218.02),
    'ranku + New': (5602.895,4986.042,4567.25,4324.832,4114.922),
    'OUR': (5382.522,4835.597,4452.018,4234.765,4046.473),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Makespan', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.07)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.legend(bbox_to_anchor=(0.99, 0.99), loc=1, borderaxespad=0)
plt.savefig('./figs/s_layer_makespan.pdf')
plt.show()

# %%
penguin_means_l = {
    'HEFT': (5707.863,5112.285,4710.195,4460.958,4257.141),
    'New priority + EFT': (5561.803,5009.492,4635.313,4397.563,4218.02),
    'ranku + New': (5602.895,4986.042,4567.25,4324.832,4114.922),
    'OUR': (5382.522,4835.597,4452.018,4234.765,4046.473),
}

penguin_means_p = {
    'HEFT': (6084.853,5084.47,4424.937,3969.044,3687.005),
    'New priority + EFT': (5938.81,4938.426,4281.674,3829.66,3557.454),
    'ranku + New': (5994.891,4975.864,4331.14,3886.479,3624.457),
    'OUR': (5765.066,4698.066,4033.112,3598.408,3319.627),
}

# %%
sum = 0
for i in range(5):
    sum += (penguin_means_l['New priority + EFT'][i] - penguin_means_l['HEFT'][i]) / penguin_means_l['HEFT'][i]
    sum += (penguin_means_p['New priority + EFT'][i] - penguin_means_p['HEFT'][i]) / penguin_means_p['HEFT'][i]

sum / 10
# Out:
# -0.02403506120441281

# %%
sum = 0
for i in range(5):
    sum += (penguin_means_l['OUR'][i] - penguin_means_l['ranku + New'][i]) / penguin_means_l['ranku + New'][i]
    sum += (penguin_means_p['OUR'][i] - penguin_means_p['ranku + New'][i]) / penguin_means_p['ranku + New'][i]

sum / 10
# Out:
# -0.04533965619071552

# %%
sum = 0
for i in range(5):
    sum += (penguin_means_l['New priority + EFT'][i] - penguin_means_l['HEFT'][i]) / penguin_means_l['HEFT'][i]
    sum += (penguin_means_l['OUR'][i] - penguin_means_l['ranku + New'][i]) / penguin_means_l['ranku + New'][i]

sum / 10
# Out:
# -0.021718991449533785

# %%
sum = 0
for i in range(5):
    sum += (penguin_means_p['New priority + EFT'][i] - penguin_means_p['HEFT'][i]) / penguin_means_p['HEFT'][i]
    sum += (penguin_means_p['OUR'][i] - penguin_means_p['ranku + New'][i]) / penguin_means_p['ranku + New'][i]

sum / 10
# Out:
# -0.04765572594559454

# %%
sum = 0
for i in range(5):
    # sum += (penguin_means_l['ranku + New'][i] - penguin_means_l['HEFT'][i]) / penguin_means_l['HEFT'][i]
    sum += (penguin_means_p['ranku + New'][i] - penguin_means_p['HEFT'][i]) / penguin_means_p['HEFT'][i]

sum / 5
# Out:
# -0.019021793664370172

# %%
sum = 0
for i in range(5):
    # sum += (penguin_means_l['OUR'][i] - penguin_means_l['New priority + EFT'][i]) / penguin_means_p['New priority + EFT'][i]
    sum += (penguin_means_p['OUR'][i] - penguin_means_p['New priority + EFT'][i]) / penguin_means_p['New priority + EFT'][i]

sum / 5
# Out:
# -0.05264344402030868

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (1.423,1.474,1.515,1.567,1.613),
    'New priority + EFT': (1.386,1.446,1.492,1.549,1.6),
    'ranku + New': (1.394,1.434,1.461,1.514,1.552),
    'OUR': (1.337,1.391,1.429,1.489,1.532),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SLR', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
plt.rcParams.update({'font.size': 12})
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.07)

plt.tick_params(labelsize=15)
plt.savefig('./figs/s_layer_SLR.pdf')
plt.show()

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (3.35,3.787,4.119,4.374,4.617),
    'New priority + EFT': (3.434,3.853,4.179,4.42,4.653),
    'ranku + New': (3.419,3.898,4.275,4.532,4.805),
    'OUR': (3.564,4.009,4.363,4.599,4.86),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Speedup', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
plt.rcParams.update({'font.size': 12})
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-0.08, 0)

plt.legend(bbox_to_anchor=(0.99,0.01), loc=4, borderaxespad=0)
plt.tick_params(labelsize=15)
plt.savefig('./figs/s_layer_speed.pdf')
plt.show()

# %% [markdown]
# 2. paral

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (6084.853,5084.47,4424.937,3969.044,3687.005),
    'New priority + EFT': (5938.81,4938.426,4281.674,3829.66,3557.454),
    'ranku + New': (5994.891,4975.864,4331.14,3886.479,3624.457),
    'OUR': (5765.066,4698.066,4033.112,3598.408,3319.627),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Makespan', fontsize=20)
ax.set_title('DAG with different paralisms', fontsize=20)
ax.set_xticks(x + width, species)
plt.rcParams.update({'font.size': 12})
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.11)

plt.tick_params(labelsize=15)
plt.legend(bbox_to_anchor=(0.01, 0.99), loc=2, borderaxespad=0)
plt.savefig('./figs/s_paral_makespan.pdf')
plt.show()

# %%
print(penguin_means['OUR'])
# Out:
# (0.05255459745699695, 0.07599690823232322, 0.08854928330053057, 0.09338168082792732, 0.09964130778233285)

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (1.382,1.547,1.714,1.905,2.064),
    'New priority + EFT': (1.346,1.5,1.658,1.836,1.988),
    'ranku + New': (1.361,1.513,1.675,1.868,2.028),
    'OUR': (1.301,1.425,1.556,1.721,1.853),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SLR', fontsize=20)
ax.set_title('DAG with different paralisms', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.12)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/s_paral_SLR.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (3.136,3.752,4.293,4.76,5.166),
    'New priority + EFT': (3.221,3.871,4.439,4.935,5.363),
    'ranku + New': (3.186,3.838,4.391,4.854,5.256),
    'OUR': (3.335,4.077,4.729,5.263,5.751),
}

for key, value in penguin_means.items():
    if(key == 'HEFT'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['HEFT'], penguin_means[key]))

del penguin_means['HEFT']

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Speedup', fontsize=20)
ax.set_title('DAG with different paralisms', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-0.12, 0)

plt.legend(bbox_to_anchor=(0.01,0.01), loc=3, borderaxespad=0)
plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/s_paral_speed.pdf')
plt.show()
