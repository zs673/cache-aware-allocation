# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C467B0A9F0>

# %% [markdown]
# # layer

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (5707.863,5112.285,4710.195,4460.958,4257.141),
    'CPOP': (6148.311,5566.51,5102.425,4843.99,4633.925),
    'ranku + New': (5602.895,4986.042,4567.25,4324.832,4114.922),
    'New priority + EFT': (5561.803,5009.492,4635.313,4397.563,4218.02),
    'OUR': (5382.522,4835.597,4452.018,4234.765,4046.473),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Makespan', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.16)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/o_layer_makespan.pdf')
plt.show()

# %%
penguin_means = {
    'HEFT': (5707.863,5112.285,4710.195,4460.958,4257.141),
    'CPOP': (6148.311,5566.51,5102.425,4843.99,4633.925),
    'ranku + New': (5602.895,4986.042,4567.25,4324.832,4114.922),
    'New priority + EFT': (5561.803,5009.492,4635.313,4397.563,4218.02),
    'OUR': (5382.522,4835.597,4452.018,4234.765,4046.473),
}

for key, value in penguin_means.items():
    if(key == 'OUR'):
        continue

    sum = 0
    for i in range(5):
        sum += (penguin_means['OUR'][i] - penguin_means[key][i]) / penguin_means[key][i]
    penguin_means[key] = sum / 5

penguin_means
# Out:
# {'HEFT': -0.0532248240229247,
#  'CPOP': -0.12717392272012393,
#  'ranku + New': -0.02643903352969119,
#  'New priority + EFT': -0.036836137572598134,
#  'OUR': (5382.522, 4835.597, 4452.018, 4234.765, 4046.473)}

# %%
penguin_means = {
    'HEFT': (6084.853,5084.47,4424.937,3969.044,3687.005),
    'CPOP': (6573.68,5356.668,4577.245,4042.557,3719.543),
    'ranku + New': (5994.891,4975.864,4331.14,3886.479,3624.457),
    'New priority + EFT': (5938.81,4938.426,4281.674,3829.66,3557.454),
    'OUR': (5765.066,4698.066,4033.112,3598.408,3319.627),
}

for key, value in penguin_means.items():
    if(key == 'OUR'):
        continue

    sum = 0
    for i in range(5):
        sum += (penguin_means['OUR'][i] - penguin_means[key][i]) / penguin_means[key][i]
    penguin_means[key] = sum / 5

penguin_means
# Out:
# {'HEFT': -0.08202475552002217,
#  'CPOP': -0.1164442868817813,
#  'ranku + New': -0.06424027885173984,
#  'New priority + EFT': -0.05264344402030868,
#  'OUR': (5765.066, 4698.066, 4033.112, 3598.408, 3319.627)}

# %%
penguin_means_l = {
    'HEFT': (5707.863,5112.285,4710.195,4460.958,4257.141),
    'CPOP': (6148.311,5566.51,5102.425,4843.99,4633.925),
    'ranku + New': (5602.895,4986.042,4567.25,4324.832,4114.922),
    'New priority + EFT': (5561.803,5009.492,4635.313,4397.563,4218.02),
    'OUR': (5382.522,4835.597,4452.018,4234.765,4046.473),
}
penguin_means_p = {
    'HEFT': (6084.853,5084.47,4424.937,3969.044,3687.005),
    'CPOP': (6573.68,5356.668,4577.245,4042.557,3719.543),
    'ranku + New': (5994.891,4975.864,4331.14,3886.479,3624.457),
    'New priority + EFT': (5938.81,4938.426,4281.674,3829.66,3557.454),
    'OUR': (5765.066,4698.066,4033.112,3598.408,3319.627),
}

for key, value in penguin_means_l.items():
    if(key == 'OUR'):
        continue

    sum = 0
    for i in range(5):
        sum += (penguin_means_l['OUR'][i] - penguin_means_l[key][i]) / penguin_means_l[key][i]
        sum += (penguin_means_p['OUR'][i] - penguin_means_p[key][i]) / penguin_means_p[key][i]
    penguin_means_l[key] = sum / 10

penguin_means_l
# Out:
# {'HEFT': -0.06762478977147343,
#  'CPOP': -0.12180910480095261,
#  'ranku + New': -0.04533965619071552,
#  'New priority + EFT': -0.044739790796453405,
#  'OUR': (5382.522, 4835.597, 4452.018, 4234.765, 4046.473)}

# %%
print(penguin_means['OUR'])
# Out:
# (0.12455274302162005, 0.1313054319492825, 0.12747017349593578, 0.1257692522073744, 0.1267720129264069)

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (1.423,1.474,1.515,1.567,1.613),
    'CPOP': (1.521,1.589,1.625,1.681,1.733),
    'ranku + New': (1.394,1.434,1.461,1.514,1.552),
    'New priority + EFT': (1.386,1.446,1.492,1.549,1.6),
    'OUR': (1.337,1.391,1.429,1.489,1.532),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SLR', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.15)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/o_layer_SLR.pdf')
plt.show()

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (3.35,3.787,4.119,4.374,4.617),
    'CPOP': (3.128,3.509,3.842,4.074,4.3),
    'ranku + New': (3.419,3.898,4.275,4.532,4.805),
    'New priority + EFT': (3.434,3.853,4.179,4.42,4.653),
    'OUR': (3.564,4.009,4.363,4.599,4.86),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Speedup', fontsize=20)
ax.set_title('DAG with different layers', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-0.18, 0)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.legend(bbox_to_anchor=(0.99,0.01), loc=4, borderaxespad=0)
plt.savefig('./figs/o_layer_speed.pdf')
plt.show()

# %% [markdown]
# # paral

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (6084.853,5084.47,4424.937,3969.044,3687.005),
    'CPOP': (6573.68,5356.668,4577.245,4042.557,3719.543),
    'ranku + New': (5994.891,4975.864,4331.14,3886.479,3624.457),
    'New priority + EFT': (5938.81,4938.426,4281.674,3829.66,3557.454),
    'OUR': (5765.066,4698.066,4033.112,3598.408,3319.627),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Makespan', fontsize=20)
ax.set_title('DAG with different parallelisms', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.15)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/o_paral_makespan.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (1.382,1.547,1.714,1.905,2.064),
    'CPOP': (1.477,1.619,1.761,1.933,2.073),
    'ranku + New': (1.361,1.513,1.675,1.868,2.028),
    'New priority + EFT': (1.346,1.5,1.658,1.836,1.988),
    'OUR': (1.301,1.425,1.556,1.721,1.853),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('SLR', fontsize=20)
ax.set_title('DAG with different parallelisms', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 0.15)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.savefig('./figs/o_paral_SLR.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

species = ("10", "15", "20", "25", "30")
penguin_means = {
    'HEFT': (3.136,3.752,4.293,4.76,5.166),
    'CPOP': (2.933,3.588,4.18,4.688,5.14),
    'ranku + New': (3.186,3.838,4.391,4.854,5.256),
    'New priority + EFT': (3.221,3.871,4.439,4.935,5.363),
    'OUR': (3.335,4.077,4.729,5.263,5.751),
}

for key, value in penguin_means.items():
    if(key == 'CPOP'):
        continue
    penguin_means[key] =  tuple((a - b) / a for a, b in zip(penguin_means['CPOP'], penguin_means[key]))

del penguin_means['CPOP']

x = np.arange(len(species))  # the label locations
width = 0.2  # the width of the bars
multiplier = -0.5

fig, ax = plt.subplots(layout='constrained',figsize=(7,5))#

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Speedup', fontsize=20)
ax.set_title('DAG with different parallelisms', fontsize=20)
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(-0.18, 0)

plt.rcParams.update({'font.size': 12})
plt.tick_params(labelsize=15)
plt.legend(bbox_to_anchor=(0.99,0.01), loc=4, borderaxespad=0)
plt.savefig('./figs/o_paral_speed.pdf')
plt.show()
