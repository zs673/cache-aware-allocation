# %%
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x000001C467B0A9F0>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
x_labels = ['10', '15', '20', '25', '30']
methods = ['RTSS2020','sen+old','sen+new','HEFT+new','CPOP','OUR']
'''data = [[0.939,0.933,0.928,0.9,0.989,0.874],#54
[0.933,0.926,0.92,0.888,0.989,0.869],#51
[0.939,0.922,0.919,0.878,0.987,0.861],#58--20
[0.938,0.92,0.922,0.886,0.991,0.879],#43
[0.947,0.929,0.934,0.892,0.99,0.88]]#46'''
data = [[1,0.598,0.589,0.586,0.569,0.63,0.553],#54
[1,0.626,0.617,0.613,0.591,0.659,0.579],#51
[0.999,0.64,0.63,0.626,0.602,0.672,0.592],#58--20
[1,0.658,0.649,0.643,0.618,0.689,0.609],#43
[1,0.675,0.666,0.661,0.633,0.709,0.627]]#46
# 遍历每一行
for row in data:
    # 获取第二列的元素
    second_element = row[3]
    
    # 对该行的每个元素进行操作
    for i in range(len(row)):
        # 减去第二列的元素，并除以第二列的元素
        row[i] = (second_element - row[i]) / second_element
    
    # 删除第二列
    del row[3]
data = np.array(data)#5*6

# 设置柱状图参数
bar_width = 0.15
x = np.arange(len(x_labels))
colors = ['r', 'g', 'b', 'c', 'm', 'y']

# 绘制并列柱状图
fig, ax = plt.subplots(figsize=(20,10))
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[:, i], width=bar_width, label=methods[i])

# 设置图例和标签
ax.set_xticks(x + (len(methods) - 1) * bar_width / 2)
ax.set_xticklabels(x_labels)
ax.legend()

# 设置x轴标签和标题
plt.xlabel('maxlayers', fontsize=20)
plt.ylabel('avg_makespan_percent', fontsize=20)
plt.title('Differ maxlayers', fontsize=20)
plt.ylim(-0.8,0.1)

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
x_labels = ['10', '15', '20', '25', '30']
methods = ['RTSS2020','sen+old','sen+new','HEFT+new','CPOP','OUR']
'''data = [[8111.898,4715.045,4640.086,4616.964,4476.908,4972.355,4352.878],
[1120.16,1111.16,1103.88,1067.6,1187.34,1043.6],
[1032.54,1014.82,1011.12,968.9,1093.98,947.32],
[987.28,969.46,971.34,935.46,1050.24,925.56],
[916.02,897.28,903.1,861.68,964.56,850.2]]'''
data = [[8111.898,4715.045,4640.086,4616.964,4476.908,4972.355,4352.878],
[7305.332,4445.172,4380.79,4359.992,4200.707,4685.764,4115.213],
[6748.01,4203.566,4133.277,4102.965,3954.239,4418.53,3877.332],
[6361.689,4056.609,3999.746,3963.488,3811.584,4260.179,3751.363],
[6050.858,3933.013,3879.946,3849.486,3689.089,4151.538,3649.305]]
# 遍历每一行
for row in data:
    # 获取第二列的元素
    second_element = row[3]
    
    # 对该行的每个元素进行操作
    for i in range(len(row)):
        # 减去第二列的元素，并除以第二列的元素
        row[i] = (second_element - row[i]) / second_element
    
    # 删除第二列
    del row[3]
data = np.array(data)#5*6

# 设置柱状图参数
bar_width = 0.15
x = np.arange(len(x_labels))
colors = ['r', 'g', 'b', 'c', 'm', 'y']

# 绘制并列柱状图
fig, ax = plt.subplots(figsize=(20,10))
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[:, i], width=bar_width, label=methods[i])

# 设置图例和标签
ax.set_xticks(x + (len(methods) - 1) * bar_width / 2)
ax.set_xticklabels(x_labels)
ax.legend()

# 设置x轴标签和标题
plt.xlabel('maxlayers', fontsize=20)
plt.ylabel('avg_makespan_abs', fontsize=20)
plt.title('Differ maxlayers', fontsize=20)
plt.ylim(-0.8,0.1)

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
x_labels = ['10', '15', '20', '25', '30']
methods = ['RTSS2020','sen+old','sen+new','HEFT+new','CPOP','OUR']
'''data = [[1.43,1.421,1.413,1.37,1.504,1.331],
[1.535,1.519,1.512,1.459,1.622,1.426],
[1.581,1.549,1.546,1.475,1.654,1.448],
[1.663,1.633,1.636,1.567,1.753,1.559],
[1.801,1.767,1.775,1.694,1.875,1.675]]'''
data = [[2.708,1.577,1.552,1.544,1.498,1.652,1.456],
[2.655,1.621,1.597,1.588,1.53,1.696,1.498],
[2.695,1.687,1.661,1.65,1.587,1.763,1.559],
[2.676,1.725,1.701,1.687,1.62,1.8,1.597],
[2.644,1.753,1.731,1.718,1.644,1.836,1.629]]
# 遍历每一行
for row in data:
    # 获取第二列的元素
    second_element = row[3]
    
    # 对该行的每个元素进行操作
    for i in range(len(row)):
        # 减去第二列的元素，并除以第二列的元素
        row[i] = (second_element - row[i]) / second_element
    
    # 删除第二列
    del row[3]
data = np.array(data)#5*6

# 设置柱状图参数
bar_width = 0.15
x = np.arange(len(x_labels))
colors = ['r', 'g', 'b', 'c', 'm', 'y']

# 绘制并列柱状图
fig, ax = plt.subplots(figsize=(20,10))
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[:, i], width=bar_width, label=methods[i])

# 设置图例和标签
ax.set_xticks(x + (len(methods) - 1) * bar_width / 2)
ax.set_xticklabels(x_labels)
ax.legend()

# 设置x轴标签和标题
plt.xlabel('maxlayers', fontsize=20)
plt.ylabel('avg_SLR', fontsize=20)
plt.title('Differ maxlayers', fontsize=20)
plt.ylim(-0.8,0.1)

# 显示图形
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
x_labels = ['10', '15', '20', '25', '30']
methods = ['RTSS2020','sen+old','sen+new','HEFT+new','CPOP','OUR']
'''data = [[3.345,3.368,3.385,3.493,3.187,3.594],
[3.663,3.689,3.714,3.85,3.438,3.941],
[4.004,4.081,4.094,4.293,3.821,4.366],
[4.189,4.27,4.261,4.449,3.966,4.471],
[4.549,4.636,4.62,4.833,4.367,4.89]]'''
data = [[2.262,3.787,3.864,3.865,3.984,3.609,4.1],
[2.529,4.033,4.093,4.116,4.272,3.852,4.36],
[2.752,4.272,4.339,4.366,4.543,4.088,4.619],
[2.953,4.456,4.518,4.555,4.745,4.271,4.81],
[3.131,4.602,4.66,4.695,4.906,4.395,4.946]]
# 遍历每一行
for row in data:
    # 获取第二列的元素
    second_element = row[3]
    
    # 对该行的每个元素进行操作
    for i in range(len(row)):
        # 减去第二列的元素，并除以第二列的元素
        row[i] = (second_element - row[i]) / second_element
    
    # 删除第二列
    del row[3]
data = np.array(data)#5*6

# 设置柱状图参数
bar_width = 0.15
x = np.arange(len(x_labels))
colors = ['r', 'g', 'b', 'c', 'm', 'y']

# 绘制并列柱状图
fig, ax = plt.subplots(figsize=(20,10))
for i in range(len(methods)):
    ax.bar(x + i * bar_width, data[:, i], width=bar_width, label=methods[i])

# 设置图例和标签
ax.set_xticks(x + (len(methods) - 1) * bar_width / 2)
ax.set_xticklabels(x_labels)
ax.legend()

# 设置x轴标签和标题
plt.xlabel('maxlayers', fontsize=20)
plt.ylabel('avg_speed_up', fontsize=20)
plt.title('Differ maxlayers', fontsize=20)
plt.ylim(-0.1,0.5)

# 显示图形
plt.show()
